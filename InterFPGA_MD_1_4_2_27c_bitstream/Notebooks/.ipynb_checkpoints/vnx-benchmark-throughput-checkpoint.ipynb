# %%
from MD_ctrl import *

iter_target = 100

# Board init
ol_w0, ol_w1 = init_network()
ol_w0_md = init_kernel(ol_w0, 1, iter_target)
ol_w1_md = init_kernel(ol_w1, 7, iter_target)
print("Boards initialized. ")
ol_w0_md.register_map.dest_id = 7
ol_w1_md.register_map.dest_id = 1

# Pos init
ol_w0_md.register_map.MD_state = 1   # 0: IDLE; 1: INIT; 2: READY_TO_RECV; 3: RUN
ol_w1_md.register_map.MD_state = 1

ol_w0_md.register_map.init_step = 0
ol_w1_md.register_map.init_step = 0
mm2s = init_pos(ol_w0, 0, 15, 7)  # 2^22 4194304
mm2s = init_pos(ol_w1, 0, 15, 1)  # 2^21 2097152
ol_w0_md.register_map.init_step = 1
ol_w1_md.register_map.init_step = 1
mm2s = init_pos(ol_w0, 0, 15, 7)  # 2^22 4194304
mm2s = init_pos(ol_w1, 0, 15, 1)  # 2^21 2097152

print("Pos initialized. ")
print()
print("local in traffic size in 512", check_status(ol_w0_md, "in_traffic_bytes_pos")/64)
print("remote out traffic size in 512", check_status(ol_w1_md, "out_traffic_bytes_pos")/64)
print("remote in traffic size in 512", check_status(ol_w1_md, "in_traffic_bytes_pos")/64)
print("local out traffic size in 512", check_status(ol_w0_md, "out_traffic_bytes_pos")/64)
print()

# Recv step 0
s2mm_w0, s2mm_buf_w0 = init_recv(ol_w0, 15)
s2mm_w1, s2mm_buf_w1 = init_recv(ol_w1, 15)


# Ready to receive
ol_w0_md.register_map.MD_state = 2
ol_w1_md.register_map.MD_state = 2
time.sleep(1)

# Start transferring
ol_w0_md.register_map.MD_state = 3
ol_w1_md.register_map.MD_state = 3
while (int(ol_w0_md.register_map.iter_cnt) < iter_target or int(ol_w1_md.register_map.iter_cnt) < iter_target ):
    time.sleep(1)
time.sleep(1)
start_recv(s2mm_buf_w0, "./recv_local_step_0.txt")
start_recv(s2mm_buf_w1, "./recv_remote_step_0.txt")

print("Step 0 received. ")
# # Recv step 1
# s2mm_buf_w0 = init_recv(ol_w0, 112)
# s2mm_buf_w1 = init_recv(ol_w1, 112)
# ol_w0_md.register_map.init_step = 1
# ol_w1_md.register_map.init_step = 1
# start_recv(s2mm_buf_w0, "./recv_local_step_1.txt")
# start_recv(s2mm_buf_w1, "./recv_remote_step_1.txt")
# print("Step 1 received. ")

print()
print("Local still receiving: ", s2mm_w0.register_map.CTRL.AP_START)
print("Local still receiving: ", s2mm_w1.register_map.CTRL.AP_START)

print()
print("local in traffic size in 512", check_status(ol_w0_md, "in_traffic_bytes_pos")/64)
print("remote out traffic size in 512", check_status(ol_w1_md, "out_traffic_bytes_pos")/64)
print("remote in traffic size in 512", check_status(ol_w1_md, "in_traffic_bytes_pos")/64)
print("local out traffic size in 512", check_status(ol_w0_md, "out_traffic_bytes_pos")/64)
# Out:
# Boards initialized.
# [15  0  0  0 15  0  0  0 15  0  0  0 15  0  0  0 15  0  0  0 15  0  0  0
#  15  0  0  0 15  0  0  0 15  0  0  0 15  0  0  0 15  0  0  0 15  0  0  0
#  15  0  0  0 15  0  0  0 15  0  0  0 15  0  0  0  0  0  8  0  0  0  8  0
#   0  0  8  0  1  0  0  0  0  0  8  0  0  0  8  0  0  0  8  0  1  0  0  0
#   0  0  8  0  0  0  8  0  0  0  8  0  1  0  0  0  0  0  8  0  0  0  8  0
#   0  0  8  0  1  0  0  0  0  0 16  0  0  0 16  0  0  0 16  0  1  0  0  
#  1572864 1572864       0 2097152 2097152 2097152       0 2097152 2097152
#  2097152       0 2097152 2097152 2097152       0 2097152 2097152 2097152
#        0 2621440 2621440 2621440       0 2621440 2621440 2621440       0
#  2621440 2621440 2621440       0 2621440 2621440 2621440       0 3145728
#  3145728 3145728       0 3145728 3145728 3145728       0 3145728 3145728
#  3145728       0 3145728 3145728 3145728       0 3670016 3670016 3670016
#        0 3670016 3670016 3670016       0 3670016 3670016 3670016       0
#  3670016 3670016 3670016       0 4194304 4194304 4194304       0 4194304
#  4194304 4194304       0 4194304 4194304 4194304       0 4194304 4194304
#  4194304       0 4718592 4718592 4718592       0 4718592 4718592 4718592
#        0 4718592 4718592 4718592       0 4718592 4718592 4718592       0
#  5242880 5242880 5242880       0 5242880 5242880 5242880       0 5242880
#  5242880 5242880       0 5242880 5242880 5242880       0 5767168 5767168
#  5767168       0 5767168 5767168 5767168       0 5767168 5767168 5767168
#        0 5767168 5767168 5767168       0 6291456 6291456 6291456       0
#  6291456 6291456 6291456       0 6291456 6291456 6291456       0 6291456
#  6291456 6291456       0 6815744 6815744 6815744       0 6815744 6815744
#  6815744       0 6815744 6815744 6815744       0 6815744 6815744 6815744
#        0 7340184 7340184 7340184       0 7340184 7340184 7340184       0
#  7340184 7340184 7340184       0 7340184 7340184 7340184       0 7871066
#  7871066 7871066       0 7871066 7871066 7871066       0 7871066 7871066
#  7871066       0 7871066 7871066 7871066       0]
# Step 0 received.
#
# Local still receiving:  0
# Local still receiving:  0
#
# local in traffic size in 512 32.0
# remote out traffic size in 512 32.0
# remote in traffic size in 512 32.0
# local out traffic size in 512 32.0

# %%
print(ol_w0_md.register_map)
print(ol_w1_md.register_map)
# Out:
# RegisterMap {
#   CTRL = Register(AP_START=1, AP_DONE=0, AP_IDLE=0, AP_READY=0, AUTO_RESTART=0),
#   MD_state = Register(value=3),
#   dest_id = Register(value=7),
#   number_packets = Register(value=0),
#   init_id = Register(value=1),
#   init_step = Register(value=0),
#   reset_fsm = Register(value=0),
#   debug_fsms = Register(value=0),
#   out_traffic_cycles_pos = Register(value=812046475),
#   out_traffic_bytes_pos = Register(value=1920),
#   out_traffic_packets_pos = Register(value=2),
#   in_traffic_cycles_pos = Register(value=810214576),
#   in_traffic_bytes_pos = Register(value=1920),
#   in_traffic_packets_pos = Register(value=2),
#   summary_cycles = Register(value=0),
#   summary_bytes = Register(value=0),
#   summary_packets = Register(value=0),
#   debug_reset = Register(value=0),
#   out_traffic_cycles_frc = Register(value=18),
#   out_traffic_bytes_frc = Register(value=896),
#   out_traffic_packets_frc = Register(value=14),
#   in_traffic_cycles_frc = Register(value=42),
#   in_traffic_bytes_frc = Register(value=896),
#   in_traffic_packets_frc = Register(value=14),
#   fifo_pos_full = Register(value=0),
#   fifo_frc_full = Register(value=0),
#   all_dirty = Register(value=0),
#   disp_back_pressure = Register(value=0),
#   home_buf_almost_full = Register(value=0),
#   nb_buf_almost_full = Register(value=0),
#   all_frc_output_ring_buf_empty = Register(value=1),
#   all_frc_output_ring_done = Register(value=1),
#   all_home_buf_empty = Register(value=1),
#   all_nb_buf_empty = Register(value=1),
#   all_disp_buf_empty = Register(value=1),
#   all_MU_buf_empty = Register(value=1),
#   chk_nb_frc = Register(value=1),
#   chk_home_frc = Register(value=1),
#   chk_MU_vel_out = Register(value=1),
#   chk_MU_vel_produced = Register(value=1),
#   chk_MU_offset_in = Register(value=1),
#   MU_num_particles = Register(value=14),
#   MU_rd_cnt = Register(value=30),
#   iter_cnt = Register(value=2),
#   iter_target = Register(value=2),
#   operation_cycle_cnt = Register(value=2028),
#   MU_migration_flag = Register(value=1),
#   num_particles_0 = Register(value=14),
#   num_particles_1 = Register(value=14),
#   num_particles_2 = Register(value=14),
#   num_particles_3 = Register(value=14),
#   num_particles_4 = Register(value=14),
#   num_particles_5 = Register(value=14),
#   num_particles_6 = Register(value=14),
#   num_particles_7 = Register(value=14)
# }
# RegisterMap {
#   CTRL = Register(AP_START=1, AP_DONE=0, AP_IDLE=0, AP_READY=0, AUTO_RESTART=0),
#   MD_state = Register(value=3),
#   dest_id = Register(value=1),
#   number_packets = Register(value=0),
#   init_id = Register(value=7),
#   init_step = Register(value=0),
#   reset_fsm = Register(value=0),
#   debug_fsms = Register(value=0),
#   out_traffic_cycles_pos = Register(value=810214575),
#   out_traffic_bytes_pos = Register(value=1920),
#   out_traffic_packets_pos = Register(value=2),
#   in_traffic_cycles_pos = Register(value=812046475),
#   in_traffic_bytes_pos = Register(value=1920),
#   in_traffic_packets_pos = Register(value=2),
#   summary_cycles = Register(value=0),
#   summary_bytes = Register(value=0),
#   summary_packets = Register(value=0),
#   debug_reset = Register(value=0),
#   out_traffic_cycles_frc = Register(value=18),
#   out_traffic_bytes_frc = Register(value=896),
#   out_traffic_packets_frc = Register(value=14),
#   in_traffic_cycles_frc = Register(value=43),
#   in_traffic_bytes_frc = Register(value=896),
#   in_traffic_packets_frc = Register(value=14),
#   fifo_pos_full = Register(value=0),
#   fifo_frc_full = Register(value=0),
#   all_dirty = Register(value=0),
#   disp_back_pressure = Register(value=0),
#   home_buf_almost_full = Register(value=0),
#   nb_buf_almost_full = Register(value=0),
#   all_frc_output_ring_buf_empty = Register(value=1),
#   all_frc_output_ring_done = Register(value=1),
#   all_home_buf_empty = Register(value=1),
#   all_nb_buf_empty = Register(value=1),
#   all_disp_buf_empty = Register(value=1),
#   all_MU_buf_empty = Register(value=1),
#   chk_nb_frc = Register(value=1),
#   chk_home_frc = Register(value=1),
#   chk_MU_vel_out = Register(value=1),
#   chk_MU_vel_produced = Register(value=1),
#   chk_MU_offset_in = Register(value=1),
#   MU_num_particles = Register(value=14),
#   MU_rd_cnt = Register(value=30),
#   iter_cnt = Register(value=2),
#   iter_target = Register(value=2),
#   operation_cycle_cnt = Register(value=2028),
#   MU_migration_flag = Register(value=1),
#   num_particles_0 = Register(value=14),
#   num_particles_1 = Register(value=14),
#   num_particles_2 = Register(value=14),
#   num_particles_3 = Register(value=14),
#   num_particles_4 = Register(value=14),
#   num_particles_5 = Register(value=14),
#   num_particles_6 = Register(value=14),
#   num_particles_7 = Register(value=14)
# }
